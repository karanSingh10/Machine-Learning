# %% [markdown]
# #Connecting Google Drive

# %% [markdown]
# #Importing Libraries

# %% [markdown]
# #Importing Data

# %% [markdown]
# #Getting sense of data

# %% [markdown]
# #EDA and Feature Engineering

# %% [markdown]
# ##Checking null values

# %% [markdown]
# ##Extracting year and month

# %% [markdown]
# ##Dropping duplicate and correlated features

# %% [markdown]
# ##One Hot Encoding

# %% [markdown]
# ##Scaling the data(Not neede for RF, DT and MLP

# %% [markdown]
# #Building Individual Models

# %% [markdown]
# #Building stacked models
